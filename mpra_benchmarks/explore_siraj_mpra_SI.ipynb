# %%
"""
This notebook contains code to download and process MPRA data from Siraj et al. (2024)
https://www.biorxiv.org/content/10.1101/2024.05.05.592437v1"

The processed data are provided as part of this github repo.
"""
# Out:
# '\nThis notebook contains code to download and process MPRA data from Siraj et al. (2024)\nhttps://www.biorxiv.org/content/10.1101/2024.05.05.592437v1"\n\nThe processed data are provided as part of this github repo.\n'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import spearmanr, pearsonr

# %%
print("Run in console or uncomment os.system call")
print("wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-4.xlsx")
# import os; os.system("wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-4.xlsx")
# Out:
# Run in console or uncomment os.system call
# wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-4.xlsx

# %%
df = pd.read_excel("media-4.xlsx", engine="openpyxl", skiprows=1)

# %%
col = ["variant", "active.any", "emVar.any"] + [c for c in df.columns if c.endswith("K562")]
k562 = df[col]
k562.to_csv("media-4-K562_allelic_mpra.tsv.gz", sep="\t", index=False)

# %%
print("Run in console or uncomment os.system call")
print("wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-7.xlsx")
# import os; os.system("wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-7.xlsx")
# Out:
# Run in console or uncomment os.system call
# wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-7.xlsx

# %%
saturation = pd.read_excel("media-7.xlsx", engine="openpyxl", skiprows=1)

# %%
saturation[saturation["Cell Type"] == "K562"].to_csv("media-7-K562_saturation.tsv.gz", sep="\t", index=False)

# %%
print("Run in console or uncomment os.system call")
print("wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-3.xlsx")
#import os; os.system("wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-3.xlsx")
# Out:
# Run in console or uncomment os.system call
# wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-3.xlsx

# %%
oligos = pd.read_excel("media-3.xlsx", engine="openpyxl", skiprows=1)
oligos[["chrom", "pos", "a1", "a2"]] = oligos["Variant"].str.split(':', expand=True)
oligos.to_csv("media-3_oligos.tsv.gz", sep="\t", index=False)

# %%
oligos_snps = oligos[(oligos["a1"].str.len() == 1) * (oligos["a2"].str.len() == 1)]
oligos_snps.to_csv("media-3_oligos_snps.tsv.gz", sep="\t", index=False)

# %%
print("Run in console or uncomment os.system call")
print("wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-2.xlsx")
# import os; os.system("wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-2.xlsx")
# Out:
# Run in console or uncomment os.system call
# wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-2.xlsx

# %%
finemap = pd.read_excel("media-2.xlsx", engine="openpyxl", skiprows=1)
finemap.to_csv("media-2_finemap.tsv.gz", sep="\t", index=False)

# %%
print("Run in console or uncomment os.system call")
print("wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-6.xlsx")
# import os; os.system("wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-6.xlsx")
# Out:
# Run in console or uncomment os.system call
# wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-6.xlsx

# %%
epistasis = pd.read_excel("media-6.xlsx", engine="openpyxl", skiprows=1)
epistasis.to_csv("media-6_epistasis.tsv.gz", sep="\t", index=False)

# %%
print("Run in console or uncomment os.system call")
print("wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-5.xlsx")
# import os; os.system("wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-5.xlsx")
# Out:
# Run in console or uncomment os.system call
# wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-5.xlsx

# %%
specificity = pd.read_excel("media-5.xlsx", engine="openpyxl", skiprows=1)
specificity.to_csv("media-5_cell_type_specificity.tsv.gz", sep="\t", index=False)

# %%
print("Run in console or uncomment os.system call")
print("wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-8.xlsx")
# import os; os.system("wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-8.xlsx")
# Out:
# Run in console or uncomment os.system call
# wget https://www.biorxiv.org/content/biorxiv/early/2024/05/06/2024.05.05.592437/DC4/embed/media-8.xlsx

# %%
cre = pd.read_excel("media-8.xlsx", engine="openpyxl", skiprows=1)
cre.to_csv("media-8_cre_definition.tsv.gz", sep="\t", index=False)

# %%
df = pd.read_csv("media-4-K562_allelic_mpra.tsv.gz", sep="\t")

# %%
sns.distplot(df[df["emVar_K562"] == 1]["log2FC_K562"])
sns.distplot(df[df["emVar_K562"] == 0]["log2FC_K562"])
# Out:
# /Users/adamhe/miniforge3/envs/plt/lib/python3.12/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/adamhe/miniforge3/envs/plt/lib/python3.12/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <Axes: xlabel='log2FC_K562', ylabel='Density'>

# %%
norm = np.log2((df["mean_RNA_ref_K562"] / df["mean_Plasmid_ref_K562"]) / (df["mean_RNA_alt_K562"] / df["mean_Plasmid_alt_K562"]))
unnorm = np.log2((df["mean_RNA_ref_K562"]) / (df["mean_RNA_alt_K562"]))

# %%
np.abs((norm).loc[df["emVar_K562"] == 1]).min()
# Out:
# 0.07198199770565993

# %%
sns.distplot((norm).loc[df["emVar_K562"] == 1])
sns.distplot((norm).loc[df["emVar_K562"] == 0])
# Out:
# /Users/adamhe/miniforge3/envs/plt/lib/python3.12/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/adamhe/miniforge3/envs/plt/lib/python3.12/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <Axes: ylabel='Density'>

# %%
sns.kdeplot((unnorm).loc[df["emVar_K562"] == 1])
sns.kdeplot((unnorm).loc[df["emVar_K562"] == 0])
# Out:
# <Axes: ylabel='Density'>

# %%
data=pd.read_csv("predictions.csv.gz")

# %%
sp = sns.scatterplot(x=data.expt, y=data.pred)
sp.set(xlim=(-10, 10), ylim=(-1, 1))
# Out:
# [(-10.0, 10.0), (-1.0, 1.0)]

# %%
sp = sns.scatterplot(x=data.expt, y=data.pred_p)
sp.set(xlim=(-10, 10), ylim=(-0.01, 0.01))
# Out:
# [(-10.0, 10.0), (-0.01, 0.01)]

# %%
sp = sns.scatterplot(x=data.expt, y=data.pred_p_2114)
sp.set(xlim=(-10, 10), ylim=(-0.005, 0.005))
# Out:
# [(-10.0, 10.0), (-0.005, 0.005)]

# %%
print(pearsonr(data.dropna().expt, data.dropna().pred))
print(pearsonr(data.dropna().expt, data.dropna().pred_p))
print(pearsonr(data.dropna().expt, data.dropna().pred_p_2114))
# Out:
# PearsonRResult(statistic=0.24444149991647549, pvalue=0.0)
# PearsonRResult(statistic=0.025086406588856264, pvalue=3.072458556823213e-40)
# PearsonRResult(statistic=0.011927073558357742, pvalue=2.745571900731804e-10)

# %%
print(spearmanr(data.dropna().expt, data.dropna().pred))
print(spearmanr(data.dropna().expt, data.dropna().pred_p))
print(spearmanr(data.dropna().expt, data.dropna().pred_p_2114))
# Out:
# SignificanceResult(statistic=0.1533684558541155, pvalue=0.0)
# SignificanceResult(statistic=0.026485445013323075, pvalue=1.1827261816659273e-44)
# SignificanceResult(statistic=0.01096947006002973, pvalue=6.411599328616355e-09)
